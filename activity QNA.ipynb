# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Simi.Jacob\OneDrive - EY\ICT\qna11\student-data.csv')

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   internet romantic  famrel  freetime  goout Dalc Walc health absences passed
# 0       no       no       4         3      4    1    1      3        6     no
# 1      yes       no       5         3      3    1    1      3        4     no
# 2      yes       no       4         3      2    2    3      3       10    yes
# 3      yes      yes       3         2      2    1    1      5        2    yes
# 4       no       no       4         3      2    1    2      5        4    yes
#
# [5 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'passed'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# passed        0
# dtype: int64

# %%
for i in df.columns:
    print(i,df[i].unique())
# Out:
# school ['GP' 'MS']
# sex ['F' 'M']
# age [18 17 15 16 19 22 20 21]
# address ['U' 'R']
# famsize ['GT3' 'LE3']
# Pstatus ['A' 'T']
# Medu [4 1 3 2 0]
# Fedu [4 1 2 3 0]
# Mjob ['at_home' 'health' 'other' 'services' 'teacher']
# Fjob ['teacher' 'other' 'services' 'health' 'at_home']
# reason ['course' 'other' 'home' 'reputation']
# guardian ['mother' 'father' 'other']
# traveltime [2 1 3 4]
# studytime [2 3 1 4]
# failures [0 3 2 1]
# schoolsup ['yes' 'no']
# famsup ['no' 'yes']
# paid ['no' 'yes']
# activities ['no' 'yes']
# nursery ['yes' 'no']
# higher ['yes' 'no']
# internet ['no' 'yes']
# romantic ['no' 'yes']
# famrel [4 5 3 1 2]
# freetime [3 2 4 1 5]
# goout [4 3 2 1 5]
# Dalc [1 2 5 3 4]
# Walc [1 3 2 4 5]
# health [3 5 1 2 4]
# absences [ 6  4 10  2  0 16 14  7  8 25 12 54 18 26 20 56 24 28  5 13 15 22  3 21
#   1 75 30 19  9 11 38 40 23 17]
# passed ['no' 'yes']

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# goout       0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# ...

# %%
numerical_features=[feature for feature in dataset.columns if dataset[feature].dtypes!='O']

# %%
cat_features=[feature  for feature in df.columns if df[feature].dtype=='O']
cat_features
# Out:
# ['school',
#  'sex',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'schoolsup',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'higher',
#  'internet',
#  'romantic',
#  'passed']

# %%
numerical_features=[feature  for feature in df.columns  if df[feature].dtype!='O']
numerical_features
# Out:
# ['age',
#  'Medu',
#  'Fedu',
#  'traveltime',
#  'studytime',
#  'failures',
#  'famrel',
#  'freetime',
#  'goout',
#  'Dalc',
#  'Walc',
#  'health',
#  'absences']

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
for i in cat_features:
    print(i, df[i].nunique())
# Out:
# school 2
# sex 2
# address 2
# famsize 2
# Pstatus 2
# Mjob 5
# Fjob 5
# reason 4
# guardian 3
# schoolsup 2
# famsup 2
# paid 2
# activities 2
# nursery 2
# higher 2
# internet 2
# romantic 2
# passed 2

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
le = LabelEncoder()
for i in ["sex", "famsize","Pstatus"]:
    df[i] = le.fit_transform(df[i])

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'passed'],
#       dtype='object')

# %%
for i in ['sex', 'address', 'famsize', 'Pstatus', 'schoolsup', 'famsup', 'paid','activities','nursery','higher','internet','romantic']:
    y = pd.get_dummies(df[i], prefix=i)
    df = pd.concat([df, y], axis=1)

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'passed', 'sex_0', 'sex_1', 'address_R',
#        'address_U', 'famsize_0', 'famsize_1', 'Pstatus_0', 'Pstatus_1',
#        'schoolsup_no', 'schoolsup_yes', 'famsup_no', 'famsup_yes', 'paid_no',
#        'paid_yes', 'activities_no', 'activities_yes', 'nursery_no',
#        'nursery_yes', 'higher_no', 'higher_yes', 'internet_no', 'internet_yes',
#        'romantic_no', 'romantic_yes'],
#       dtype='object')

# %%
df= df.drop(['sex', 'address', 'famsize', 'Pstatus', 'schoolsup', 'famsup', 'paid','activities','nursery','higher','internet','romantic'], axis=1)

# %%
df.columns
# Out:
# Index(['school', 'age', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian',
#        'traveltime', 'studytime', 'failures', 'famrel', 'freetime', 'goout',
#        'Dalc', 'Walc', 'health', 'absences', 'passed', 'sex_0', 'sex_1',
#        'address_R', 'address_U', 'famsize_0', 'famsize_1', 'Pstatus_0',
#        'Pstatus_1', 'schoolsup_no', 'schoolsup_yes', 'famsup_no', 'famsup_yes',
#        'paid_no', 'paid_yes', 'activities_no', 'activities_yes', 'nursery_no',
#        'nursery_yes', 'higher_no', 'higher_yes', 'internet_no', 'internet_yes',
#        'romantic_no', 'romantic_yes'],
#       dtype='object')

# %%
df= df.drop(['school','sex_1','address_U','famsize_1', 'Pstatus_1','schoolsup_yes',
             'famsup_yes',
       'paid_no',  'activities_no', 'nursery_no',
       'higher_no', 'internet_no', 
      'romantic_yes'], axis=1)

# %%
df.columns
# Out:
# Index(['age', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian',
#        'traveltime', 'studytime', 'failures', 'famrel', 'freetime', 'goout',
#        'Dalc', 'Walc', 'health', 'absences', 'passed', 'sex_0', 'address_R',
#        'famsize_0', 'Pstatus_0', 'schoolsup_no', 'famsup_no', 'paid_yes',
#        'activities_yes', 'nursery_yes', 'higher_yes', 'internet_yes',
#        'romantic_no'],
#       dtype='object')

# %%
for i in df.columns:
    print(i,df[i].unique())
# Out:
# age [18 17 15 16 19 22 20 21]
# Medu [4 1 3 2 0]
# Fedu [4 1 2 3 0]
# Mjob ['at_home' 'health' 'other' 'services' 'teacher']
# Fjob ['teacher' 'other' 'services' 'health' 'at_home']
# reason ['course' 'other' 'home' 'reputation']
# guardian ['mother' 'father' 'other']
# traveltime [2 1 3 4]
# studytime [2 3 1 4]
# failures [0 3 2 1]
# famrel [4 5 3 1 2]
# freetime [3 2 4 1 5]
# goout [4 3 2 1 5]
# Dalc [1 2 5 3 4]
# Walc [1 3 2 4 5]
# health [3 5 1 2 4]
# absences [ 6  4 10  2  0 16 14  7  8 25 12 54 18 26 20 56 24 28  5 13 15 22  3 21
#   1 75 30 19  9 11 38 40 23 17]
# passed ['no' 'yes']
# sex_0 [1 0]
# address_R [0 1]
# famsize_0 [1 0]
# Pstatus_0 [1 0]
# schoolsup_no [0 1]
# famsup_no [1 0]
# paid_yes [0 1]
# activities_yes [0 1]
# nursery_yes [1 0]
# higher_yes [1 0]
# internet_yes [0 1]
# romantic_no [1 0]

# %%
for i in ['Mjob', 'Fjob', 'reason', 'guardian']:
    multi_class = pd.get_dummies(df[i], prefix=i)
    df_imp1 = pd.concat([df, multi_class], axis=1)

# %%
df_imp1.columns
# Out:
# Index(['age', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian',
#        'traveltime', 'studytime', 'failures', 'famrel', 'freetime', 'goout',
#        'Dalc', 'Walc', 'health', 'absences', 'passed', 'sex_0', 'address_R',
#        'famsize_0', 'Pstatus_0', 'schoolsup_no', 'famsup_no', 'paid_yes',
#        'activities_yes', 'nursery_yes', 'higher_yes', 'internet_yes',
#        'romantic_no', 'guardian_father', 'guardian_mother', 'guardian_other'],
#       dtype='object')

# %%
df_imp1= df_imp1.drop(['Mjob', 'Fjob', 'reason', 'guardian'], axis=1)

# %%
le = LabelEncoder()
for i in ["passed"]:
    df_imp1[i] = le.fit_transform(df_imp1[i])

# %%
df_imp1 =df_imp1.drop(['passed'], axis = 1)

# %%
df_imp1.columns
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'sex_0',
#        'address_R', 'famsize_0', 'Pstatus_0', 'schoolsup_no', 'famsup_no',
#        'paid_yes', 'activities_yes', 'nursery_yes', 'higher_yes',
#        'internet_yes', 'romantic_no', 'guardian_father', 'guardian_mother',
#        'guardian_other'],
#       dtype='object')

# %%
df_target = df['paid_yes']

# %%
from sklearn.model_selection import train_test_split

# %%
train = 300
test=len(df_imp1.index)-train
X_train, X_test, y_train, y_test = train_test_split(df_imp1, df_target, stratify = df_target, test_size=test, random_state=42)
print ("Training set =",X_train.shape[0]," samples.")
print ("Testing set =",X_test.shape[0]," samples.")
# Out:
# Training set = 300  samples.
# Testing set = 95  samples.

# %%
from sklearn.svm import SVC
from sklearn.metrics import f1_score

SvM = SVC(random_state=42)

# %%
SvM.fit(X_train, y_train)
SvM_y_pred_train = SvM.predict(X_train)
SvM_y_pred_test = SvM.predict(X_test)
SvM_train_score = f1_score(y_train.values, SvM_y_pred_train)
SvM_test_score = f1_score(y_test.values, SvM_y_pred_test) 
print("SVC: F1 score{train:",SvM_train_score, ", test:",SvM_test_score,"}")
# Out:
# SVC: F1 score{train: 0.8185654008438819 , test: 0.8607594936708862 }
